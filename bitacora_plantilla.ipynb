# %% [markdown]
# # Bitácora — Modelos generativos profundos
# **Diplomado en Inteligencia Artificial Aplicada · DGTIC-UNAM**
#
# | | |
# |---|---|
# | **Nombre** | _(escriba aquí)_ |
# | **Proyecto integrador** | _(una línea)_ |
# | **Fecha de inicio** | 28 de agosto de 2026 |
#
# > **Qué es esto.** Su única bitácora del módulo — y su único entregable.
# > No son ocho prácticas sueltas: cada ejercicio agrega UNA sección a
# > este cuaderno, y al terminar la Sesión 4 esta bitácora ES su
# > mini-proyecto. Para entregar, descárguela (Archivo → Descargar →
# > .ipynb) y súbala a la plataforma del diplomado.
# >
# > ⚠️ **Guarde una copia propia AHORA**: Archivo → Guardar una copia
# > en Drive. Si trabaja sobre el original, pierde todo al cerrar.
#
# ### Cómo se entrega — cuatro momentos, ningún trabajo nuevo
#
# | Cuándo | Qué subo | Vale |
# |---|---|---|
# | Al cerrar **cada sesión** | Esta bitácora con las 2 secciones del día | 40 % |
# | **Jueves 3 de septiembre**, 23:59 | Secciones **§1 a §4** + el párrafo de «qué falló» | 15 % |
# | **Sábado 12 de septiembre**, 23:59 | Bitácora completa **§1 a §9** + 1 cuartilla divulgativa | 35 % |
# | En las Sesiones 3 y 4 | Seminario por equipos (3 diapositivas, 5 min) y los 3 formularios de repaso | 10 % |
#
# Las dos entregas son **cortes de este mismo cuaderno**: no hay reporte
# aparte, ni portada, ni formato especial. Si usó una celda de rescate,
# sólo dígalo — no descuenta puntos.
#
# ---

# %%
#### OBLIGATORIO #### — setup (idempotente: puede ejecutarla dos veces)
import os, sys
if not os.path.isdir("src"):
    if not os.path.isdir("IAA6_M13_Gen"):
        # !git clone -q https://github.com/AdriannaGmz/IAA6_M13_Gen
    # %cd IAA6_M13_Gen
# !pip install -q -r requirements.txt
sys.path.insert(0, ".")
from src import datos, modelos, evaluar, graficas, rescate
MODO_GPU = rescate.hay_gpu()   # imprime "GPU disponible" o "Modo CPU"

# %% [markdown]
# ## §1 · El molde
# *(Se llena en S1-E1.)*
#
# - **Mi x es:** ___
# - **Mi y es:** ___
# - **Escribo mi proyecto como:** p( ___ | ___ )
# - **Clase minoritaria:** ___ con ___ muestras ( ___ %)
# - _(Pegue aquí la ficha de datos y la figura de vistazo.)_
#
# ---

# %% [markdown]
# ## §2 · Mi primer generador
# *(Se llena en S1-E2.)*
#
# - _(Pegue la rejilla de muestras y la figura de interpolación.)_
# - **La pérdida bajó:** sí / no
# - **Las muestras se ven:** nítidas / borrosas
# - _(No explique todavía por qué: se responde en la Sesión 2.)_
#
# ---

# %% [markdown]
# ## §3 · El juego (VAE vs GAN)
# *(Se llena en S2-E1.)*
#
# - _(Pegue la comparación VAE vs GAN.)_
# - **Cobertura de modos equilibrada:** ___
# - **Cobertura de modos tras desbalancear (lr_d = 10·lr_g):** ___
# - ⚠️ **Guarde estos dos números: se usan en la Sesión 4.**
#
# ---

# %% [markdown]
# ## §4 · Control (nace el mini-proyecto)
# *(Se llena en S2-E2.)*
#
# - _(Pegue las muestras condicionadas de SU clase minoritaria.)_
# - **Archivo sintético guardado en:** ___
# - **¿Son verosímiles? ¿Son todas iguales?** ___
#
# ---

# %% [markdown]
# ## ⬆ Hasta aquí llega la **Primera Entrega** · jueves 3 de septiembre, 23:59
#
# Suba este mismo cuaderno con las secciones **§1 a §4** — lo que hizo en
# las Sesiones 1 y 2 — y nada más. No es trabajo nuevo.
#
# **El párrafo honesto** — es lo único que no sale de una celda, y son 5 de
# los 15 puntos de esta entrega:
#
# - **Qué intenté:** ___
# - **Qué NO me salió:** ___
# - **Mi mejor hipótesis de por qué:** ___
#
# > Un resultado pobre bien documentado vale los puntos completos del
# > inciso; un resultado bonito sin análisis, no. Si usó las celdas de
# > rescate, dígalo aquí: es válido y no descuenta.
#
# ---

# %% [markdown]
# ## §5 · Difusión desde cero en 2D
# *(Se llena en S3-E1.)*
#
# - _(Pegue la secuencia del ruido convirtiéndose en la distribución.)_
# - **En una línea: ¿qué se diseñó y qué se aprendió?** ___
#
# ---

# %% [markdown]
# ## §6 · Control fino
# *(Se llena en S3-E2.)*
#
# - _(Pegue la rejilla pasos × guía.)_
# - **Mi hipótesis previa decía:** ___
# - **Lo que observé:** ___
#
# ---

# %% [markdown]
# ## §7 · Adaptar sin reentrenar
# *(Se llena en S4-E1.)*
#
# - _(Pegue la comparación antes/después.)_
# - **Qué logré controlar:** ___
# - **Qué no:** ___
#
# ---

# %% [markdown]
# ## §8 · El juicio (TSTR)
# *(Se llena en S4-E2.)*
#
# - _(Pegue la tabla de tres renglones: línea base / TSTR / aumentado.)_
# - **Conclusión honesta (un resultado negativo es un resultado válido):**
#   ___
#
# ---

# %% [markdown]
# ## §9 · Límites y riesgos
# *(Se llena para la Segunda Entrega, con lo visto en la Sesión 4.)*
#
# - **Procedencia de mis datos:** ___
# - **Qué región de mi dominio queda subrepresentada:** ___
# - **Qué riesgo de los vistos en la S4 aplica a mi caso:** ___
# - **Una funcionalidad que podría implementar y decido no implementar:** ___

# %% [markdown]
# ---
#
# ## ⬆ Hasta aquí llega la **Segunda Entrega** · sábado 12 de septiembre, 23:59
#
# Suba esta bitácora completa (**§1 a §9**) y, aparte, **una cuartilla**
# escrita para alguien que no es del área — por ejemplo su jefe, o un
# colega de otro departamento. Tres cosas, nada más:
#
# 1. Qué problema tiene y qué quiso generar, contado sin tecnicismos.
# 2. Qué modelo usó y cuál es su punto débil: calidad, cobertura o
#    velocidad — el trilema, en palabras llanas.
# 3. Si los datos que generó sirven o todavía no.
#
# > Máximo una cuartilla: la brevedad es parte del ejercicio. Y la regla
# > de todo el módulo — que el resultado salga negativo es un resultado
# > válido y entregable; se evalúa la honestidad del análisis, no que el
# > número salga bonito.
